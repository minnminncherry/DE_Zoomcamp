# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
pd.__version__
# Out:
# '2.1.0'

# %%
df = pd.read_csv("yello_head.csv", nrows = 100)

# %%
df
# Out:
#     VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0          1  2021-07-01 00:08:51   2021-07-01 00:13:05                1
# 1          1  2021-07-01 00:22:39   2021-07-01 00:25:58                1
# 2          1  2021-07-01 00:48:33   2021-07-01 00:54:58                1
# 3          1  2021-07-01 00:59:44   2021-07-01 01:07:09                1
# 4          1  2021-07-01 00:08:35   2021-07-01 00:16:28                0
# ..       ...                  ...                   ...              ...
# 94         1  2021-07-01 00:00:16   2021-07-01 00:14:11                1
# 95         1  2021-07-01 00:35:21   2021-07-01 00:40:49                1
# 96         2  2021-07-01 00:04:34   2021-07-01 00:20:15                2
# 97         2  2021-07-01 00:29:29   2021-07-01 00:36:14                3
# 98         1  2021-07-01 00:12:37   2021-07-01 00:22:54                1
#
#     trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0            0.80           1                  N            90            68
# 1            0.90           1                  N           113            90
# 2            2.80           1                  N            88           232
# 3            1.40           1                  N            79           249
# 4            2.00           1                  N           142           238
# ..            ...         ...                ...           ...           ...
# 94           4.20           1                  N            13            48
# 95           1.40           1                  N           249            68
# 96           3.11           1                  N            48             4
# 97           2.84           1                  N            79           140
# 98           2.00           1                  N            41           116
#
#     payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 0              1          5.0    3.0      0.5        0.00           0.0
# 1              2          5.0    3.0      0.5        0.00           0.0
# 2              2         10.0    3.0      0.5        0.00           0.0
# 3              1          7.0    3.0      0.5        1.50           0.0
# 4              1          8.5    3.0      0.5        0.00           0.0
# ..           ...          ...    ...      ...         ...           ...
# 94             1         14.5    3.0      0.5        3.65           0.0
# 95             1          6.5    3.0      0.5        2.55           0.0
# 96             1         13.5    0.5      0.5        3.46           0.0
# 97             1          9.5    0.5      0.5        3.32           0.0
# 98             2          9.5    0.5      0.5        0.00           0.0
#
#     improvement_surcharge  total_amount  congestion_surcharge
# 0                     0.3          8.80                   2.5
# 1                     0.3          8.80                   2.5
# 2                     0.3         13.80                   2.5
# 3                     0.3         12.30                   2.5
# 4                     0.3         12.30                   2.5
# ..                    ...           ...                   ...
# 94                    0.3         21.95                   2.5
# 95                    0.3         12.85                   2.5
# 96                    0.3         20.76                   2.5
# 97                    0.3         16.62                   2.5
# 98                    0.3         10.80                   0.0
#
# [99 rows x 18 columns]

# %%
df.tpep_pickup_datetime = pd.to_datetime(df.tpep_pickup_datetime)
df.tpep_dropoff_datetime = pd.to_datetime(df.tpep_dropoff_datetime)

# %%
engine = create_engine('postgresql://root:root@localhost:5432/de_test')

# %%
engine.connect()

# %%
print(pd.io.sql.get_schema(df, name = 'yello_taxi_date', con=engine))
# Out:
# CREATE TABLE yello_taxi_date (
# 	"VendorID" BIGINT,
# 	tpep_pickup_datetime TIMESTAMP WITHOUT TIME ZONE,
# 	tpep_dropoff_datetime TIMESTAMP WITHOUT TIME ZONE,
# 	passenger_count BIGINT,
# 	trip_distance FLOAT(53),
# 	"RatecodeID" BIGINT,
# 	store_and_fwd_flag TEXT,
# 	"PULocationID" BIGINT,
# 	"DOLocationID" BIGINT,
# 	payment_type BIGINT,
# 	fare_amount FLOAT(53),
# 	extra FLOAT(53),
# 	mta_tax FLOAT(53),
# 	tip_amount FLOAT(53),
# 	tolls_amount FLOAT(53),
# 	improvement_surcharge FLOAT(53),
# 	total_amount FLOAT(53),
# 	congestion_surcharge FLOAT(53)
# )

# %%
df_iter = pd.read_csv('yellow_tripdata_2021-07.csv', iterator = True, chunksize = 100000)

# %%
df = next(df_iter)
df.tail()
# Out:
#        VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 99995         1  2021-07-02 08:48:33   2021-07-02 09:04:45                0
# 99996         1  2021-07-02 08:33:48   2021-07-02 08:39:06                1
# 99997         1  2021-07-02 08:41:40   2021-07-02 08:48:48                1
# 99998         1  2021-07-02 08:53:00   2021-07-02 09:01:30                1
# 99999         2  2021-07-02 08:21:00   2021-07-02 08:25:00                1
#
#        trip_distance  RatecodeID store_and_fwd_flag  PULocationID  \
# 99995           5.10           1                  N           141
# 99996           1.10           1                  N           107
# 99997           1.40           1                  N           170
# 99998           1.50           1                  N           229
# 99999           0.74           1                  N           237
#
#        DOLocationID  payment_type  fare_amount  extra  mta_tax  tip_amount  \
# 99995             4             1         16.5    3.0      0.5        5.00
# 99996           170             1          6.0    2.5      0.5        7.00
# 99997           141             2          7.0    2.5      0.5        0.00
# 99998           263             1          8.0    2.5      0.5        2.00
# 99999           262             1          5.0    0.0      0.5        1.66
#
#        tolls_amount  improvement_surcharge  total_amount  congestion_surcharge
# 99995           0.0                    0.3         25.30                   2.5
# 99996           0.0                    0.3         16.30                   2.5
# 99997           0.0                    0.3         10.30                   2.5
# 99998           0.0                    0.3         13.30                   2.5
# 99999           0.0                    0.3          9.96                   2.5

# %%
len(df)
# Out:
# 100000

# %%
df.tpep_pickup_datetime = pd.to_datetime(df.tpep_pickup_datetime)
df.tpep_dropoff_datetime = pd.to_datetime(df.tpep_dropoff_datetime)

# %%
df.head(n=1)
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         1  2021-07-01 00:08:51   2021-07-01 00:13:05                1
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0            0.8           1                  N            90            68
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 0             1          5.0    3.0      0.5         0.0           0.0
#
#    improvement_surcharge  total_amount  congestion_surcharge
# 0                    0.3           8.8                   2.5

# %%
print(pd.io.sql.get_schema(df, name = 'yello_taxi_data', con=engine))
# Out:
# CREATE TABLE yello_taxi_data (
# 	"VendorID" BIGINT,
# 	tpep_pickup_datetime TIMESTAMP WITHOUT TIME ZONE,
# 	tpep_dropoff_datetime TIMESTAMP WITHOUT TIME ZONE,
# 	passenger_count BIGINT,
# 	trip_distance FLOAT(53),
# 	"RatecodeID" BIGINT,
# 	store_and_fwd_flag TEXT,
# 	"PULocationID" BIGINT,
# 	"DOLocationID" BIGINT,
# 	payment_type BIGINT,
# 	fare_amount FLOAT(53),
# 	extra FLOAT(53),
# 	mta_tax FLOAT(53),
# 	tip_amount FLOAT(53),
# 	tolls_amount FLOAT(53),
# 	improvement_surcharge FLOAT(53),
# 	total_amount FLOAT(53),
# 	congestion_surcharge FLOAT(53)
# )

# %%
df.to_sql(name = 'yellow_taxi_data', con = engine, if_exists='replace')
# df
# Out:
# 1000

# %%
# %time df.to_sql(name='yellow_taxi_data', con=engine ,if_exists='append')
# Out:
# CPU times: user 3.1 s, sys: 9.42 ms, total: 3.11 s
# Wall time: 5.76 s
# 1000

# %%
from time import time

# %%
while True:
    t_start = time()
    
    df = next(df_iter)
    
    df.tpep_pickup_datetime = pd.to_datetime(df.tpep_pickup_datetime)
    df.tpep_dropoff_datetime = pd.to_datetime(df.tpep_dropoff_datetime)
    
    df.to_sql(name='yellow_taxi_data', con=engine ,if_exists='append')
    
    t_end = time()
    
    print ('insert another chuk, took %.3f sechond' % (t_end - t_start))
# Out:
# insert another chuk, took 5.288 sechond
# insert another chuk, took 5.470 sechond
# insert another chuk, took 5.899 sechond
# insert another chuk, took 5.710 sechond
# insert another chuk, took 6.096 sechond
# insert another chuk, took 6.205 sechond
# insert another chuk, took 6.387 sechond
# insert another chuk, took 6.278 sechond
# insert another chuk, took 7.171 sechond
# insert another chuk, took 6.929 sechond
# insert another chuk, took 6.367 sechond
# insert another chuk, took 7.154 sechond
# insert another chuk, took 6.694 sechond
# insert another chuk, took 6.659 sechond
# insert another chuk, took 6.208 sechond
# insert another chuk, took 5.866 sechond
# insert another chuk, took 6.202 sechond
# insert another chuk, took 6.285 sechond
# insert another chuk, took 5.982 sechond
# insert another chuk, took 5.804 sechond
# insert another chuk, took 6.189 sechond
# insert another chuk, took 6.367 sechond
# insert another chuk, took 5.911 sechond
# insert another chuk, took 5.467 sechond
# insert another chuk, took 5.670 sechond
# /tmp/ipykernel_59358/2780248720.py:4: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = next(df_iter)
# insert another chuk, took 5.572 sechond
# insert another chuk, took 4.998 sechond
# insert another chuk, took 1.056 sechond
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[20], line 4
#       1 while True:
#       2     t_start = time()
# ----> 4     df = next(df_iter)
#       6     df.tpep_pickup_datetime = pd.to_datetime(df.tpep_pickup_datetime)
#       7     df.tpep_dropoff_datetime = pd.to_datetime(df.tpep_dropoff_datetime)
#
# File ~/py310/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1668, in TextFileReader.__next__(self)
#    1666 def __next__(self) -> DataFrame:
#    1667     try:
# -> 1668         return self.get_chunk()
#    1669     except StopIteration:
#    1670         self.close()
#
# File ~/py310/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1777, in TextFileReader.get_chunk(self, size)
#    1775         raise StopIteration
#    1776     size = min(size, self.nrows - self._currow)
# -> 1777 return self.read(nrows=size)
#
# File ~/py310/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1748, in TextFileReader.read(self, nrows)
#    1741 nrows = validate_integer("nrows", nrows)
#    1742 try:
#    1743     # error: "ParserBase" has no attribute "read"
#    1744     (
#    1745         index,
#    1746         columns,
#    1747         col_dict,
# -> 1748     ) = self._engine.read(  # type: ignore[attr-defined]
#    1749         nrows
#    1750     )
#    1751 except Exception:
#    1752     self.close()
#
# File ~/py310/lib/python3.10/site-packages/pandas/io/parsers/c_parser_wrapper.py:234, in CParserWrapper.read(self, nrows)
#     232 try:
#     233     if self.low_memory:
# --> 234         chunks = self._reader.read_low_memory(nrows)
#     235         # destructive to chunks
#     236         data = _concatenate_chunks(chunks)
#
# File parsers.pyx:868, in pandas._libs.parsers.TextReader.read_low_memory()
#
# StopIteration:

# %%
query = "select * from yellow_taxi_data limit 10"
pd.read_sql(query, con = engine)
# Out:
#    index  VendorID tpep_pickup_datetime tpep_dropoff_datetime  \
# 0      0         1  2021-07-01 00:08:51   2021-07-01 00:13:05
# 1      1         1  2021-07-01 00:22:39   2021-07-01 00:25:58
# 2      2         1  2021-07-01 00:48:33   2021-07-01 00:54:58
# 3      3         1  2021-07-01 00:59:44   2021-07-01 01:07:09
# 4      4         1  2021-07-01 00:08:35   2021-07-01 00:16:28
# 5      5         1  2021-07-01 00:10:49   2021-07-01 00:18:42
# 6      6         1  2021-07-01 00:28:56   2021-07-01 00:36:11
# 7      7         1  2021-07-01 00:45:10   2021-07-01 00:52:46
# 8      8         1  2021-07-01 00:55:43   2021-07-01 01:10:56
# 9      9         1  2021-07-01 00:04:24   2021-07-01 00:13:23
#
#    passenger_count  trip_distance  RatecodeID store_and_fwd_flag  \
# 0                1            0.8           1                  N
# 1                1            0.9           1                  N
# 2                1            2.8           1                  N
# 3                1            1.4           1                  N
# 4                0            2.0           1                  N
# 5                1            1.6           1                  N
# 6                1            1.8           1                  N
# 7                1            2.0           1                  N
# 8                1            5.7           1                  N
# 9                1            1.8           1                  N
#
#    PULocationID  DOLocationID  payment_type  fare_amount  extra  mta_tax  \
# 0            90            68             1          5.0    3.0      0.5
# 1           113            90             2          5.0    3.0      0.5
# 2            88           232             2         10.0    3.0      0.5
# 3            79           249             1          7.0    3.0      0.5
# 4           142           238             1          8.5    3.0      0.5
# 5           114            90             1          7.5    3.0      0.5
# 6            90           144             1          7.5    3.0      0.5
# 7           114            48             1          8.5    3.0      0.5
# 8            48           152             2         18.5    3.0      0.5
# 9           234           148             1          8.5    3.0      0.5
#
#    tip_amount  tolls_amount  improvement_surcharge  total_amount  \
# 0        0.00           0.0                    0.3          8.80
# 1        0.00           0.0                    0.3          8.80
# 2        0.00           0.0                    0.3         13.80
# 3        1.50           0.0                    0.3         12.30
# 4        0.00           0.0                    0.3         12.30
# 5        1.50           0.0                    0.3         12.80
# 6        2.00           0.0                    0.3         13.30
# 7        2.45           0.0                    0.3         14.75
# 8        0.00           0.0                    0.3         22.30
# 9        2.45           0.0                    0.3         14.75
#
#    congestion_surcharge
# 0                   2.5
# 1                   2.5
# 2                   2.5
# 3                   2.5
# 4                   2.5
# 5                   2.5
# 6                   2.5
# 7                   2.5
# 8                   2.5
# 9                   2.5
